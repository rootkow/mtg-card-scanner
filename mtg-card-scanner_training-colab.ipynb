# %% [markdown]
# # Create model
#
# [See Google MediaPipe docs for more info.](https://developers.google.com/mediapipe/solutions/customization/object_detector)
#
# This was run in Google Colab. Adjustments may be needed to run locally.

# %%
# !python --version
# !pip install --upgrade pip
# !pip install mediapipe-model-maker

# %%
from google.colab import files
import os
import json
import tensorflow as tf
assert tf.__version__.startswith('2')

from mediapipe_model_maker import object_detector

# %%
# Pull from drive (or wherever the dataset is stored)
# !tar -zxvf /content/drive/MyDrive/datasets/mtg-card-images.tar.gz

# %%
# Remove a bunch of garbage files from the untarring process
# !ls -la data/train
# !find ./data/ -name "._*" # -exec /bin/rm {} \;

# %%
train_dataset_path = "data/train"
validation_dataset_path = "data/validation"

with open(os.path.join(train_dataset_path, "labels.json"), "r") as f:
  labels_json = json.load(f)
for category_item in labels_json["categories"]:
  print(f"{category_item['id']}: {category_item['name']}")
# Out:
# 0: background
# 1: card

# %%
###############################
# BELOW DOES NOT RUN IN COLAB #
###############################


# import matplotlib.pyplot as plt
# from matplotlib import patches, text, patheffects
# from collections import defaultdict
# import math

# def draw_outline(obj):
#   obj.set_path_effects([patheffects.Stroke(linewidth=4,  foreground='black'), patheffects.Normal()])
# def draw_box(ax, bb):
#   patch = ax.add_patch(patches.Rectangle((bb[0],bb[1]), bb[2], bb[3], fill=False, edgecolor='red', lw=2))
#   draw_outline(patch)
# def draw_text(ax, bb, txt, disp):
#   text = ax.text(bb[0],(bb[1]-disp),txt,verticalalignment='top'
#   ,color='white',fontsize=10,weight='bold')
#   draw_outline(text)
# def draw_bbox(ax, annotations_list, id_to_label, image_shape):
#   for annotation in annotations_list:
#     cat_id = annotation["category_id"]
#     bbox = annotation["bbox"]
#     draw_box(ax, bbox)
#     draw_text(ax, bbox, id_to_label[cat_id], image_shape[0] * 0.05)
# def visualize(dataset_folder, max_examples=None):
#   with open(os.path.join(dataset_folder, "labels.json"), "r") as f:
#     labels_json = json.load(f)
#   images = labels_json["images"]
#   cat_id_to_label = {item["id"]:item["name"] for item in labels_json["categories"]}
#   image_annots = defaultdict(list)
#   for annotation_obj in labels_json["annotations"]:
#     image_id = annotation_obj["image_id"]
#     image_annots[image_id].append(annotation_obj)

#   if max_examples is None:
#     max_examples = len(image_annots.items())
#   n_rows = math.ceil(max_examples / 3)
#   fig, axs = plt.subplots(n_rows, 3, figsize=(24, n_rows*8)) # 3 columns(2nd index), 8x8 for each image
#   for ind, (image_id, annotations_list) in enumerate(list(image_annots.items())[:max_examples]):
#     ax = axs[ind//3, ind%3]
#     img = plt.imread(os.path.join(dataset_folder, "images", images[image_id]["file_name"]))
#     ax.imshow(img)
#     draw_bbox(ax, annotations_list, cat_id_to_label, img.shape)
#   plt.show()

# visualize(train_dataset_path, 9)

# %%
train_data = object_detector.Dataset.from_coco_folder(train_dataset_path, cache_dir="/tmp/od_data/train")
validation_data = object_detector.Dataset.from_coco_folder(validation_dataset_path, cache_dir="/tmp/od_data/validation")
print("train_data size: ", train_data.size)
print("validation_data size: ", validation_data.size)
# Out:
# train_data size:  25
# validation_data size:  4

# %%
spec = object_detector.SupportedModels.MOBILENET_MULTI_AVG
hparams = object_detector.HParams(export_dir='exported_model')
options = object_detector.ObjectDetectorOptions(
    supported_model=spec,
    hparams=hparams
)

# %%
model = object_detector.ObjectDetector.create(
    train_data=train_data,
    validation_data=validation_data,
    options=options)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py:639: UserWarning: Input dict contained keys ['6'] which did not match any model input. They will be ignored by the model.
#   inputs = self._flatten_to_reference_inputs(inputs)
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# Downloading https://storage.googleapis.com/tf_model_garden/vision/qat/mobilenetv3.5_ssd_coco/mobilenetv3.5_ssd_i256_ckpt.tar.gz to /tmp/model_maker/object_detector/mobilenetmultiavg
# Model: "retina_net_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobile_net (MobileNet)      {'2': (None, 64, 64, 32   3704416
#                              ),
#                               '3': (None, 32, 32, 64
#                              ),
#                               '4': (None, 16, 16, 16
#                              0),
#                               '5': (None, 8, 8, 192)
#                              , '6': (None, 1, 1, 128
#                              0)}
#
#  fpn (FPN)                   {'5': (None, 8, 8, 128)   144928
#                              , '4': (None, 16, 16, 1
#                              28),
#                               '3': (None, 32, 32, 12
#                              8),
#                               '6': (None, 4, 4, 128)
#                              , '7': (None, 2, 2, 128
#                              )}
#
#  multilevel_detection_gener  multiple                  0 (unused)
#  ator (MultilevelDetectionG
#  enerator)
#
#  retina_net_head (RetinaNet  ({'3': (None, 32, 32, 1   171062
#  Head)                       8),
#                               '4': (None, 16, 16, 18
#                              ),
#                               '5': (None, 8, 8, 18),
#                               '6': (None, 4, 4, 18),
#                               '7': (None, 2, 2, 18)}
#                              , {'3': (None, 32, 32,
#                              36),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {})
#
# =================================================================
# Total params: 4020406 (15.34 MB)
# Trainable params: 3972342 (15.15 MB)
# Non-trainable params: 48064 (187.75 KB)
# _________________________________________________________________
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# WARNING:tensorflow:Gradients do not exist for variables ['conv2dbn_block_1/batch_normalization/gamma:0', 'conv2dbn_block_1/batch_normalization/beta:0', 'conv2dbn_block_2/batch_normalization/gamma:0', 'conv2dbn_block_2/batch_normalization/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['conv2dbn_block_1/batch_normalization/gamma:0', 'conv2dbn_block_1/batch_normalization/beta:0', 'conv2dbn_block_2/batch_normalization/gamma:0', 'conv2dbn_block_2/batch_normalization/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['conv2dbn_block_1/batch_normalization/gamma:0', 'conv2dbn_block_1/batch_normalization/beta:0', 'conv2dbn_block_2/batch_normalization/gamma:0', 'conv2dbn_block_2/batch_normalization/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['conv2dbn_block_1/batch_normalization/gamma:0', 'conv2dbn_block_1/batch_normalization/beta:0', 'conv2dbn_block_2/batch_normalization/gamma:0', 'conv2dbn_block_2/batch_normalization/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 3/3 [==============================] - 66s 5s/step - total_loss: 6.0691 - cls_loss: 5.8070 - box_loss: 0.0040 - model_loss: 6.0062 - val_total_loss: 1.6027 - val_cls_loss: 1.4734 - val_box_loss: 0.0013 - val_model_loss: 1.5399
# Epoch 2/30
# 3/3 [==============================] - 6s 2s/step - total_loss: 1.6628 - cls_loss: 1.3578 - box_loss: 0.0048 - model_loss: 1.6000 - val_total_loss: 1.3186 - val_cls_loss: 1.1820 - val_box_loss: 0.0015 - val_model_loss: 1.2558
# Epoch 3/30
# 3/3 [==============================] - 8s 3s/step - total_loss: 1.5011 - cls_loss: 1.2376 - box_loss: 0.0040 - model_loss: 1.4382 - val_total_loss: 1.2552 - val_cls_loss: 1.1322 - val_box_loss: 0.0012 - val_model_loss: 1.1923
# Epoch 4/30
# 3/3 [==============================] - 5s 2s/step - total_loss: 1.3513 - cls_loss: 1.1568 - box_loss: 0.0026 - model_loss: 1.2884 - val_total_loss: 1.1920 - val_cls_loss: 1.0715 - val_box_loss: 0.0012 - val_model_loss: 1.1291
# Epoch 5/30
# 3/3 [==============================] - 7s 2s/step - total_loss: 1.2256 - cls_loss: 1.0708 - box_loss: 0.0018 - model_loss: 1.1628 - val_total_loss: 1.1089 - val_cls_loss: 0.9912 - val_box_loss: 0.0011 - val_model_loss: 1.0460
# Epoch 6/30
# 3/3 [==============================] - 5s 2s/step - total_loss: 1.0808 - cls_loss: 0.9493 - box_loss: 0.0014 - model_loss: 1.0179 - val_total_loss: 1.0063 - val_cls_loss: 0.8930 - val_box_loss: 0.0010 - val_model_loss: 0.9434
# Epoch 7/30
# 3/3 [==============================] - 5s 2s/step - total_loss: 0.9694 - cls_loss: 0.8435 - box_loss: 0.0013 - model_loss: 0.9065 - val_total_loss: 0.8881 - val_cls_loss: 0.7801 - val_box_loss: 9.0254e-04 - val_model_loss: 0.8252
# Epoch 8/30
# 3/3 [==============================] - 5s 2s/step - total_loss: 0.8552 - cls_loss: 0.7232 - box_loss: 0.0014 - model_loss: 0.7924 - val_total_loss: 0.7730 - val_cls_loss: 0.6706 - val_box_loss: 7.9109e-04 - val_model_loss: 0.7102
# Epoch 9/30
# 3/3 [==============================] - 9s 3s/step - total_loss: 0.7112 - cls_loss: 0.6099 - box_loss: 7.6933e-04 - model_loss: 0.6484 - val_total_loss: 0.6894 - val_cls_loss: 0.5895 - val_box_loss: 7.4062e-04 - val_model_loss: 0.6266
# Epoch 10/30
# 3/3 [==============================] - 5s 2s/step - total_loss: 0.6278 - cls_loss: 0.5304 - box_loss: 6.8991e-04 - model_loss: 0.5649 - val_total_loss: 0.6304 - val_cls_loss: 0.5313 - val_box_loss: 7.2332e-04 - val_model_loss: 0.5675
# Epoch 11/30
# 3/3 [==============================] - 6s 2s/step - total_loss: 0
30
# 3/3 [==============================] - 5s 2s/step - total_loss: 0.2284 - cls_loss: 0.1533 - box_loss: 2.4404e-04 - model_loss: 0.1656 - val_total_loss: 0.3657 - val_cls_loss: 0.2679 - val_box_loss: 6.9960e-04 - val_model_loss: 0.3029
# Epoch 24/30
# 3/3 [==============================] - 7s 2s/step - total_loss: 0.2222 - cls_loss: 0.1473 - box_loss: 2.4145e-04 - model_loss: 0.1594 - val_total_loss: 0.3614 - val_cls_loss: 0.2637 - val_box_loss: 6.9608e-04 - val_model_loss: 0.2985
# Epoch 25/30
# 3/3 [==============================] - 5s 2s/step - total_loss: 0.2083 - cls_loss: 0.1349 - box_loss: 2.1038e-04 - model_loss: 0.1454 - val_total_loss: 0.3565 - val_cls_loss: 0.2593 - val_box_loss: 6.8609e-04 - val_model_loss: 0.2936
# Epoch 26/30
# 3/3 [==============================] - 6s 2s/step - total_loss: 0.2690 - cls_loss: 0.1695 - box_loss: 7.3244e-04 - model_loss: 0.2061 - val_total_loss: 0.3521 - val_cls_loss: 0.2555 - val_box_loss: 6.7422e-04 - val_model_loss: 0.2892
# Epoch 27/30
# 3/3 [==============================] - 7s 3s/step - total_loss: 0.2476 - cls_loss: 0.1576 - box_loss: 5.4392e-04 - model_loss: 0.1848 - val_total_loss: 0.3476 - val_cls_loss: 0.2512 - val_box_loss: 6.7035e-04 - val_model_loss: 0.2847
# Epoch 28/30
# 3/3 [==============================] - 6s 2s/step - total_loss: 0.1929 - cls_loss: 0.1206 - box_loss: 1.8709e-04 - model_loss: 0.1300 - val_total_loss: 0.3434 - val_cls_loss: 0.2471 - val_box_loss: 6.6810e-04 - val_model_loss: 0.2805
# Epoch 29/30
# 3/3 [==============================] - 7s 3s/step - total_loss: 0.2228 - cls_loss: 0.1415 - box_loss: 3.6962e-04 - model_loss: 0.1600 - val_total_loss: 0.3414 - val_cls_loss: 0.2449 - val_box_loss: 6.7207e-04 - val_model_loss: 0.2785
# Epoch 30/30
# 3/3 [==============================] - 6s 2s/step - total_loss: 0.1850 - cls_loss: 0.1135 - box_loss: 1.7352e-04 - model_loss: 0.1222 - val_total_loss: 0.3404 - val_cls_loss: 0.2434 - val_box_loss: 6.8233e-04 - val_model_loss: 0.2775

# %%
loss, coco_metrics = model.evaluate(validation_data, batch_size=4)
print(f"Validation loss: {loss}")
print(f"Validation coco metrics: {coco_metrics}")
# Out:
# 1/1 [==============================] - 1s 1s/step - total_loss: 0.3404 - cls_loss: 0.2434 - box_loss: 6.8233e-04 - model_loss: 0.2775
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.733
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.859
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.832
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.771
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.800
# Validation loss: [0.34035181999206543, 0.24336928129196167, 0.0006823342409916222, 0.27748599648475647]
# Validation coco metrics: {'AP': 0.73277, 'AP50': 0.85904115, 'AP75': 0.83168316, 'APs': -1.0, 'APm': -1.0, 'APl': 0.733074, 'ARmax1': 0.5285714, 'ARmax10': 0.7714286, 'ARmax100': 0.8, 'ARs': -1.0, 'ARm': -1.0, 'ARl': 0.8}

# %%
model.export_model()
# !ls exported_model
files.download('exported_model/model.tflite')
# Out:
# Exporting a floating point model
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py:639: UserWarning: Input dict contained keys ['6'] which did not match any model input. They will be ignored by the model.
#   inputs = self._flatten_to_reference_inputs(inputs)
# WARNING:tensorflow:Skipping full serialization of Keras layer <official.vision.modeling.retinanet_model.RetinaNetModel object at 0x7a99960dc280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.merging.add.Add object at 0x7a99fb91ee00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.merging.add.Add object at 0x7a99fb91fc70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.merging.add.Add object at 0x7a99fb913dc0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.merging.add.Add object at 0x7a99fb9354b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.merging.add.Add object at 0x7a99fb984310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <official.vision.modeling.layers.detection_generator.MultilevelDetectionGenerator object at 0x7a9a45030280>, because it is not built.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119828) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120872) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120458) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114536) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120782) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119180) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119207) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114743) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120386) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117812) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116102) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115148) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120017) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115229) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120602) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117965) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117848) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115985) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121178) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115076) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116867) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121844) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120998) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115328) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116957) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120170) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117677) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122042) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115859) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116633) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117821) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117641) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116066) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114635) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121547) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116813) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114698) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118514) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118100) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119315) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122168) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119198) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115490) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119954) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121952) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114608) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121988) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118658) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119729) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121277) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116336) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114581) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116048) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115238) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119270) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120494) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119072) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120206) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120737) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116453) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120521) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120926) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119927) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114959) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120980) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116642) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120953) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117290) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114860) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114491) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120566) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115022) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116120) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117731) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117407) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121403) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115247) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118586) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120593) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121430) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115652) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120044) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117452) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115292) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118397) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116480) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114986) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116885) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117398) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116471) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118694) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115283) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117686) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115040) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122348) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116507) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121358) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121142) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118676) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118577) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117866) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114689) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116210) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114896) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120377) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117839) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115310) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121961) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120746) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115535) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119108) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119423) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119702) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116201) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119774) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117713) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118748) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115094) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120188) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118505) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121223) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117911) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118478) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121385) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122159) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120422) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115958) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118235) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120242) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117758) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115121) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121880) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119216) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121610) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117272) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120476) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118802) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121898) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119738) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114842) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114707) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117857) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116597) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116984) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121070) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118208) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116615) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121754) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119306) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117326) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121781) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121700) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119432) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114626) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121763) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122195) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119225) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116786) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114563) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116228) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119054) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121646) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121889) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119540) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115913) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114653) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118937) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122375) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114671) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118640) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122096) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117182) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120161) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115184) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117335) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115004) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121727) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116948) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115895) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117884) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121052) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116966) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121367) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114527) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115643) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118892) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115598) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122303) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115130) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115751) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115166) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117137) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116273) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119333) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121412) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114815) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115472) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120485) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121088) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115463) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120152) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117227) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116903) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114833) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116498) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118910) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115706) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121493) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116840) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118487) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114518) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116768) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116921) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116111) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121871) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117542) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119045) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121511) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116300) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116930) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119495) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115112) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120449) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117425) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119135) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115355) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115058) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119945) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115805) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117956) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121628) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118433) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118532) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118361) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121016) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118460) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121538) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118316) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115319) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118181) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119162) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116705) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115967) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116831) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120638) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120530) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120908) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118856) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120323) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119477) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119621) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116876) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118847) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120260) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116435) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115697) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117461) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119342) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119936) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117110) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116660) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119810) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122330) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119000) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115634) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116543) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122312) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122141) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119855) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118136) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115013) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121025) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121034) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117362) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116696) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118928) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118667) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118766) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117596) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117020) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122177) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114905) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118226) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116318) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114788) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118523) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118388) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117515) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114500) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115445) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120341) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121160) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120575) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121853) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120350) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121421) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114545) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119081) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115256) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119252) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121061) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120053) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116417) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115481) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115814) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120935) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115418) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117632) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119693) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118073) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118541) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120305) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116138) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121286) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118829) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120620) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121736) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118415) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120062) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120251) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114716) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121799) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117794) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120881) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116516) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_122402) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_118334) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116021) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116606) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121718) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119378) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_116084) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_117200) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115391) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121007) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_119864) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121907) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121673) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120890) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121043) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_115337) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114887) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_120197) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_121637) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_114923) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# float_ckpt.data-00000-of-00001	float_ckpt.index  metadata.json  model.tflite
